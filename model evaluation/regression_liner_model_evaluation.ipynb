# %% [markdown]
# # Model Evaluation

# %% [markdown]
# - pandas: Handles data in tabular format.
# - numpy: Used for numerical operations.
# - matplotlib.pyplot: Plots graphs to visualize model performance.
# - sklearn.model_selection.train_test_split: Splits the dataset into training and testing sets.
# - sklearn.linear_model.LinearRegression: Implements Linear Regression for prediction.
# - sklearn.metrics: Evaluates the model using error metrics like MAE, RMSE, and R² Score.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
data =pd.read_excel("house_prices.xlsx")

# %%
df =pd.DataFrame(data)

# %%
df
# Out:
#     Size (sqft)  Bedrooms  Location Score  Price ($1000s)
# 0          1500         3             8.5             320
# 1          1800         4             9.0             450
# 2          1200         2             7.5             250
# 3          2200         4             9.2             500
# 4          1600         3             8.0             330
# 5          1400         2             7.2             270
# 6          2000         4             9.5             480
# 7          1700         3             8.3             360
# 8          1850         3             8.7             400
# 9          1950         4             9.1             460
# 10         2100         4             9.3             490
# 11         2300         5             9.6             520
# 12         1750         3             8.2             370
# 13         1550         2             7.8             300
# 14         1900         4             8.9             420
# ...

# %%
# 🎯 Features & Target

# %% [markdown]
# - X (Features): The independent variables used for predictions (Size, Bedrooms, Location Score).
# - y (Target Variable): The dependent variable (Price) that we are trying to predict.

# %%
X = df[['Size (sqft)', 'Bedrooms', 'Location Score']]
Y=df["Price ($1000s)"]

# %%
# 🏋️ Split Data into Train & Test

# %% [markdown]
# - train_test_split() splits the dataset into:
# - 80% Training Data (X_train, y_train) → Used to train the model.
# - 20% Testing Data (X_test, y_test) → Used to evaluate performance.
# - test_size=0.2: Reserves 20% of the data for testing.
# - random_state=42: Ensures reproducibility (same random split every time).

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# 🏗️ Train the Model

# %% [markdown]
# - LinearRegression() creates a linear regression model.
# - .fit(X_train, y_train) trains the model using the training dataset.

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#make prediction

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# - The trained model predicts house prices using X_test.
# - y_pred stores the predicted prices.

# %% [markdown]
# ### Evaluating Model Performance

# %%
mae = mean_absolute_error(y_test, y_pred)

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

# %%
r2 = r2_score(y_test, y_pred)

# %% [markdown]
# - Mean Absolute Error (MAE): Measures average prediction error. Lower = better.
# - Root Mean Squared Error (RMSE): Penalizes large errors. Lower = better.
# - R² Score: Measures how well the model explains variance in data.
# - 1.0 → Perfect Model
# - 0.8 - 1.0 → Good Model
# - 0.5 - 0.8 → Moderate Model
# - Below 0.5 → Poor Model

# %%
print(f"📌 Mean Absolute Error (MAE): {mae:.2f}")
print(f"📌 Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"📌 R² Score: {r2:.2f}")
# Out:
# 📌 Mean Absolute Error (MAE): 22.22
# 📌 Root Mean Squared Error (RMSE): 23.15
# 📌 R² Score: 0.96

# %% [markdown]
# ### Visualizing the model's performance

# %%
plt.scatter(y_test, y_pred, color="blue")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle="--", color="red")
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual vs Predicted House Prices")
plt.show()

# %% [markdown]
# - Scatter Plot: Shows how close predictions (y_pred) are to actual values (y_test).
# - Red Line: Represents a perfect prediction line (y = x).
# - If points are close to the line, the model is accurate.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# - Helps determine if the model is making accurate predictions.
# - MAE & RMSE indicate how much error exists in predictions.
# - R² Score tells if the model is good or bad.
# - Visualizing results helps in debugging the model.

# %% [markdown]
# - **Is Your Model Good?**
# - Based on the evaluation metrics:
#
# - 📌 Mean Absolute Error (MAE) = 22.22 → Low errors, meaning the model predicts close to actual values. ✅
# - 📌 Root Mean Squared Error (RMSE) = 23.15 → Slightly higher, but still low. ✅
# - 📌 R² Score = 0.96 → Excellent! Your model explains 96% of the variance in the data. ✅✅✅
#
# - Conclusion:
# - Your model is very good because:
#
# - High R² (0.96) means the model explains most of the data variability.
# - Low MAE and RMSE show minimal prediction errors.
